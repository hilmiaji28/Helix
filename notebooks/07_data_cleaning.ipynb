# %% [markdown]
# # HELIX Revenue Prediction
#
# ## Notebook 07 — Data Cleaning
#
# Objective
#
# Clean and validate the dataset before feature engineering.

# %%
# import library
import warnings
from pathlib import Path

warnings.filterwarnings("ignore")

import pandas as pd

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 200)

# %%
# load dataset
PROJECT_ROOT = Path("..")

RAW_DATA = PROJECT_ROOT / "data" / "raw" / "ecommerce_customer_behavior_dataset_v2.csv"

df = pd.read_csv(RAW_DATA)

df["Date"] = pd.to_datetime(df["Date"])

df.head()
